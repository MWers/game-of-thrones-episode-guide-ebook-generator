# %%
import requests

seasons = []
seasons.append(
    [('Winter_Is_Coming', '2670'),
     ('The_Kingsroad', '2674'),
     ('Lord_Snow', '2694'),
     ('Cripples,_Bastards,_and_Broken_Things', '2705'),
     ('The_Wolf_and_the_Lion', '2711'),
     ('A_Golden_Crown', '2713'),
     ('You_Win_or_You_Die', '2714'),
     ('The_Pointy_End', '2696'),
     ('Baelor', '2743'),
     ('Fire_and_Blood', '2744')])
seasons.append(
    [('The_North_Remembers', '5397'),
     ('The_Night_Lands', '5499'),
     ('What_Is_Dead_May_Never_Die', '5862'),
     ('Garden_of_Bones', '5900'),
     ('The_Ghost_of_Harrenhal', '5905'),
     ('The_Old_Gods_and_the_New', '5904'),
     ('A_Man_Without_Honor', '5903'),
     ('The_Prince_of_Winterfell', '5902'),
     ('Blackwater', '3336'),
     ('Valar_Morghulis', '5906')])
seasons.append(
    [('Valar_Dohaeris', '13504'),
     ('Dark_Wings,_Dark_Words', '13505'),
     ('Walk_of_Punishment', '13500'),
     ('And_Now_His_Watch_Is_Ended', '13506'),
     ('Kissed_by_Fire', '13507'),
     ('The_Climb', '13930'),
     ('The_Bear_and_the_Maiden_Fair_(episode)', '13509'),
     ('Second_Sons_(episode)', '14243'),
     ('The_Rains_of_Castamere_(episode)', '13508'),
     ('Mhysa', '13510')])
seasons.append(
    [('Two_Swords', '21619'),
     ('The_Lion_and_the_Rose', '21620'),
     ('Breaker_of_Chains', '21621'),
     ('Oathkeeper', '21622'),
     ('First_of_His_Name', '21757'),
     ('The_Laws_of_Gods_and_Men', '21835'),
     ('Mockingbird', '22007'),
     ('The_Mountain_and_the_Viper', '22117'),
     ('The_Watchers_on_the_Wall', '22118'),
     ('The_Children', '22119')])
seasons.append(
    [('The_Wars_To_Come', '30456'),
     ('The_House_of_Black_and_White', '30457'),
     ('High_Sparrow_(episode)', '30458'),
     ('Sons_of_the_Harpy_(episode)', '30462'),
     ('Kill_the_Boy', '30901'),
     ('Unbowed,_Unbent,_Unbroken', '30902'),
     ('The_Gift_(episode)', '30903'),
     ('Hardhome_(episode)', '32193'),
     ('The_Dance_of_Dragons', '32631'),
     ('Mother%27s_Mercy', '33482')])
seasons.append(
    [('The_Red_Woman', '40364'),
     ('Home', '40608'),
     ('Oathbreaker', '40609'),
     ('Book_of_the_Stranger', '41124'),
     ('The_Door', '41158'),
     ('Blood_of_My_Blood', '42064'),
     ('The_Broken_Man', '42065'),
     ('No_One', '44158'),
     ('Battle_of_the_Bastards_(episode)', '44463'),
     ('The_Winds_of_Winter', '44464')])
seasons.append(
    [('Dragonstone_(episode)', '54256'),
     ('Stormborn', '54257'),
     ('The_Queen%27s_Justice', '54258'),
     ('The_Spoils_of_War', '54912'),
     ('Eastwatch_(episode)', '55428'),
     ('Beyond_the_Wall_(episode)', '55794'),
     ('The_Dragon_and_the_Wolf', '56048')])
seasons.append([('Season_8,_Episode_1', '53237')])

# %%
import unicodedata

ARTICLE_TPL = ('https://gameofthrones.fandom.com'
               '/api/v1/Articles/AsSimpleJson?id={}')

with open('/Users/matt/dev/personal/game-of-thrones-episode-guide-generator/game-of-thrones-episode-guide.md', 'w') as f:
    f.write("---\n")
    f.write("title: Game of Thrones Episode Guide\n")
    f.write("author: https://gameofthrones.fandom.com/\n")
    f.write("date: Seasons 1 - 7\n")
    f.write("---\n\n")
    for season_num, season in enumerate(seasons, 1):
        f.write("# Season {}\n\n".format(season_num))
        for ep_num, (ep_slug, ep_id) in enumerate(season, 1):

            r = requests.get(ARTICLE_TPL.format(ep_id))
            article = r.json()

            for (section_num, section) in enumerate(article['sections']):
                title = section.get('title', '').replace(' (episode)', '')

                if title in ('Appearances', 'Production', 'Recap'):
                    break

                if section_num == 0:
                    print "Writing \"Season {} Episode {} - {}\"".format(
                        season_num, ep_num, title)
                    f.write("## Episode {} - {}\n\n".format(
                        ep_num, title))
                else:
                    indent = int(section['level']) + 1
                    f.write('{} {}\n\n'.format((indent * '#'), title))

                for content in section['content']:
                    text = unicodedata.normalize('NFKD', content['text']).encode('ascii','ignore')

                    f.write('{}\n\n'.format(text))
# Out:
# Writing "Season 1 Episode 1 - Winter Is Coming"
# Writing "Season 1 Episode 2 - The Kingsroad"
# Writing "Season 1 Episode 3 - Lord Snow"
# Writing "Season 1 Episode 4 - Cripples, Bastards, and Broken Things"
# Writing "Season 1 Episode 5 - The Wolf and the Lion"
# Writing "Season 1 Episode 6 - A Golden Crown"
# Writing "Season 1 Episode 7 - You Win or You Die"
# Writing "Season 1 Episode 8 - The Pointy End"
# Writing "Season 1 Episode 9 - Baelor"
# Writing "Season 1 Episode 10 - Fire and Blood"
# Writing "Season 2 Episode 1 - The North Remembers"
# Writing "Season 2 Episode 2 - The Night Lands"
# Writing "Season 2 Episode 3 - What Is Dead May Never Die"
# Writing "Season 2 Episode 4 - Garden of Bones"
# Writing "Season 2 Episode 5 - The Ghost of Harrenhal"
# Writing "Season 2 Episode 6 - The Old Gods and the New"
# Writing "Season 2 Episode 7 - A Man Without Honor"
# Writing "Season 2 Episode 8 - The Prince of Winterfell"
# Writing "Season 2 Episode 9 - Blackwater"
# Writing "Season 2 Episode 10 - Valar Morghulis"
# Writing "Season 3 Episode 1 - Valar Dohaeris"
# Writing "Season 3 Episode 2 - Dark Wings, Dark Words"
# Writing "Season 3 Episode 3 - Walk of Punishment"
# Writing "Season 3 Episode 4 - And Now His Watch Is Ended"
# Writing "Season 3 Episode 5 - Kissed by Fire"
# Writing "Season 3 Episode 6 - The Climb"
# Writing "Season 3 Episode 7 - The Bear and the Maiden Fair"
# Writing "Season 3 Episode 8 - Second Sons"
# Writing "Season 3 Episode 9 - The Rains of Castamere"
# Writing "Season 3 Episode 10 - Mhysa"
# Writing "Season 4 Episode 1 - Two Swords"
# Writing "Season 4 Episode 2 - The Lion and the Rose"
# Writing "Season 4 Episode 3 - Breaker of Chains"
# Writing "Season 4 Episode 4 - Oathkeeper"
# Writing "Season 4 Episode 5 - First of His Name"
# Writing "Season 4 Episode 6 - The Laws of Gods and Men"
# Writing "Season 4 Episode 7 - Mockingbird"
# Writing "Season 4 Episode 8 - The Mountain and the Viper"
# Writing "Season 4 Episode 9 - The Watchers on the Wall"
# Writing "Season 4 Episode 10 - The Children"
# Writing "Season 5 Episode 1 - The Wars To Come"
# Writing "Season 5 Episode 2 - The House of Black and White"
# Writing "Season 5 Episode 3 - High Sparrow"
# Writing "Season 5 Episode 4 - Sons of the Harpy"
# Writing "Season 5 Episode 5 - Kill the Boy"
# Writing "Season 5 Episode 6 - Unbowed, Unbent, Unbroken"
# Writing "Season 5 Episode 7 - The Gift"
# Writing "Season 5 Episode 8 - Hardhome"
# Writing "Season 5 Episode 9 - The Dance of Dragons"
# Writing "Season 5 Episode 10 - Mother's Mercy"
# Writing "Season 6 Episode 1 - The Red Woman"
# Writing "Season 6 Episode 2 - Home"
# Writing "Season 6 Episode 3 - Oathbreaker"
# Writing "Season 6 Episode 4 - Book of the Stranger"
# Writing "Season 6 Episode 5 - The Door"
# Writing "Season 6 Episode 6 - Blood of My Blood"
# Writing "Season 6 Episode 7 - The Broken Man"
# Writing "Season 6 Episode 8 - No One"
# Writing "Season 6 Episode 9 - Battle of the Bastards"
# Writing "Season 6 Episode 10 - The Winds of Winter"
# Writing "Season 7 Episode 1 - Dragonstone"
# Writing "Season 7 Episode 2 - Stormborn"
# Writing "Season 7 Episode 3 - The Queen's Justice"
# Writing "Season 7 Episode 4 - The Spoils of War"
# Writing "Season 7 Episode 5 - Eastwatch"
# Writing "Season 7 Episode 6 - Beyond the Wall"
# Writing "Season 7 Episode 7 - The Dragon and the Wolf"
# Writing "Season 8 Episode 1 - Season 8"
